# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def lagranz(x,y,t):
    z=0
    for j in range(len(y)):
        p1=1; p2=1
        for i in range(len(x)):
            if i==j:
                p1=p1*1; p2=p2*1   
            else: 
                p1=p1*(t-x[i])
                p2=p2*(x[j]-x[i])
        z=z+y[j]*p1/p2
    return z

# %%
x=np.array([0.38,0.49,0.99,1.09,1.19,1.40,1.71,1.72,2.04,2.38,2.53], dtype=float)
y=np.array([1.462,1.632,2.691,2.974,3.287,4.055,5.528,5.584,7.690,10.804,12.553], dtype=float)
xnew=np.linspace(np.min(x),np.max(x),20)
ynew=[lagranz(x,y,i) for i in xnew]

plt.figure(figsize=(16,8))
plt.plot(x,y,'o',xnew,ynew)
plt.grid(True)
plt.show()
# Out:
# [0.38       0.49315789 0.60631579 0.71947368 0.83263158 0.94578947
#  1.05894737 1.17210526 1.28526316 1.39842105 1.51157895 1.62473684
#  1.73789474 1.85105263 1.96421053 2.07736842 2.19052632 2.30368421
#  2.41684211 2.53      ]
